# %%
from datasets import load_dataset

dataset = load_dataset("yerevann/coco-karpathy",cache_dir='val2014')

# %%
dataset['validation']['filename']
# Out:
# ['COCO_val2014_000000184613.jpg',
#  'COCO_val2014_000000403013.jpg',
#  'COCO_val2014_000000562150.jpg',
#  'COCO_val2014_000000360772.jpg',
#  'COCO_val2014_000000340559.jpg',
#  'COCO_val2014_000000321107.jpg',
#  'COCO_val2014_000000129001.jpg',
#  'COCO_val2014_000000556616.jpg',
#  'COCO_val2014_000000472621.jpg',
#  'COCO_val2014_000000364521.jpg',
#  'COCO_val2014_000000310391.jpg',
#  'COCO_val2014_000000241876.jpg',
#  'COCO_val2014_000000462341.jpg',
#  'COCO_val2014_000000268556.jpg',
#  'COCO_val2014_000000386912.jpg',
#  'COCO_val2014_000000074331.jpg',
#  'COCO_val2014_000000078371.jpg',
#  'COCO_val2014_000000052759.jpg',
#  'COCO_val2014_000000128939.jpg',
#  'COCO_val2014_000000339974.jpg',
#  'COCO_val2014_000000009426.jpg',
#  'COCO_val2014_000000242139.jpg',
#  'COCO_val2014_000000143931.jpg',
#  'COCO_val2014_000000040102.jpg',
#  'COCO_val2014_000000403020.jpg',
#  'COCO_val2014_000000505440.jpg',
#  'COCO_val2014_000000029913.jpg',
# ...

# %%
dataset['validation']['url']
# Out:
# ['http://images.cocodataset.org/val2014/COCO_val2014_000000184613.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000403013.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000562150.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000360772.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000340559.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000321107.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000129001.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000556616.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000472621.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000364521.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000310391.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000241876.jpg',
#  'http://images.cocodataset.org/val2014/COCO_val2014_000000462341.jpg',
# ...

# %%
dataset['validation']['sentences']
# Out:
# [['A child holding a flowered umbrella and petting a yak.',
#   'A young man holding an umbrella next to a herd of cattle.',
#   'a young boy barefoot holding an umbrella touching the horn of a cow',
#   'A young boy with an umbrella who is touching the horn of a cow.',
#   'A boy holding an umbrella while standing next to livestock.'],
#  ['A narrow kitchen filled with appliances and cooking utensils.',
#   'A galley kitchen with cabinets and appliances on both sides',
#   'A hallway leading into a white kitchen with appliances.',
#   'Doorway view of a kitchen with a sink, stove, refrigerator and pantry.',
#   'The pantry door of the small kitchen is closed.'],
#  ['A little girl holding a kitten next to a blue fence.',
#   'Girl in a tank top holding a kitten in her back yard',
#   'A young girl is holding a small cat.',
#   'Girl with a yellow shirt holding a small cat',
#   'A girl smiles as she holds a kitty cat.'],
#  ['A toilet sitting in a bathroom next to a sink.',
# ...
